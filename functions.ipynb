# %%
def add(a,b):
    return a+b

# %%
add(2,4)
# Out:
# 6

# %%
# *args it pass tuple in function parameter we can pass multiple parameter at single time 
# we can rename name this function as we want 
def sum(*total):
    return total
sum (1,2,3,4,5)
# Out:
# (1, 2, 3, 4, 5)

# %%
#kwarwgs it pass dict in function paramter
def name(**student):
 return student

# %%
def student(**kwargs):

    for key, value in kwargs.items():
        print(key, ":", value)

student(
    name="Rushikesh",
    age=23,
    city="pune" 
    ""
)
# Out:
# name : Rushikesh
# age : 23
# city : pune

# %%
# nested function
def f():
    def g ():
     print('g function')
    g()
    print("F FUNCTION")   
f()
# Out:
# g function
# F FUNCTION
